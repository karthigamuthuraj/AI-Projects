# %%
import pandas as pd
df = pd.read_csv('whatsapp-chat-data.txt',header=None,on_bad_lines='skip',encoding='utf8')

# %%
df
# Out:
#                                                        0  \
# 0                                             26/01/2020
# 1                                             24/01/2020
# 2                                             26/01/2020
# 3                                             26/01/2020
# 4                                             26/01/2020
# ...                                                  ...
# 21316                                         02/10/2020
# 21317                                         02/10/2020
# 21318                                         02/10/2020
# 21319                                         02/10/2020
# 21320  https://twitter.com/DhiruCodes/status/13118735...
#
#                                                        1  \
# 0       4:19 pm - Messages and calls are end-to-end e...
# 1                           8:25 pm - Tanay Kamath (TSEC
# 2       4:19 pm - You joined using this group's invit...
# ...

# %%
# Concatenate values from columns 1, 2, and 3
df['Concatenated'] = df[[1, 2, 3]].apply(lambda row: ''.join(row.values.astype(str)), axis=1)
# Drop columns 1, 2, and 3
df = df.drop(0)
df = df.drop(columns=[1, 2, 3])

df.head(5)
# Out:
#             0                                       Concatenated
# 1  24/01/2020   8:25 pm - Tanay Kamath (TSEC CS) created grou...
# 2  26/01/2020   4:19 pm - You joined using this group's invit...
# 3  26/01/2020   4:20 pm - +91 99871 38558 joined using this g...
# 4  26/01/2020   4:20 pm - +91 91680 38866 joined using this g...
# 5  26/01/2020   4:22 pm - +91 72762 35231 joined using this g...

# %%
df.columns = ["Date","Chat"]

# %%
df.head(10)
# Out:
#           Date                                               Chat
# 1   24/01/2020   8:25 pm - Tanay Kamath (TSEC CS) created grou...
# 2   26/01/2020   4:19 pm - You joined using this group's invit...
# 3   26/01/2020   4:20 pm - +91 99871 38558 joined using this g...
# 4   26/01/2020   4:20 pm - +91 91680 38866 joined using this g...
# 5   26/01/2020   4:22 pm - +91 72762 35231 joined using this g...
# 6   26/01/2020   4:22 pm - +91 88392 06534 joined using this g...
# 7   26/01/2020   4:23 pm - +91 98709 38217 joined using this g...
# 8   26/01/2020   4:23 pm - +91 98702 02065 joined using this g...
# 9   26/01/2020   4:23 pm - +91 91370 44426 joined using this g...
# 10  26/01/2020   4:25 pm - +91 86559 19035 joined using this g...

# %%
Message = df["Chat"].str.split('-',n=1,expand=True)
Message1 = Message[1].str.split(':',n=1,expand=True)
df["Time"] = Message[0]
df["Name"] = Message1[0]
df["Chat"] = Message1[1]
df = df[["Date","Time","Name","Chat"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21320 entries, 1 to 21320
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    21320 non-null  object
#  1   Time    21320 non-null  object
#  2   Name    13586 non-null  object
#  3   Chat    13265 non-null  object
# dtypes: object(4)
# memory usage: 666.4+ KB

# %%
import nltk

nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
dataset = df

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#              Date       Time                        Name  \
# 113    27/01/2020   7:31 pm              +91 96536 93868
# 114    27/01/2020   7:31 pm              +91 96536 93868
# 115    27/01/2020   7:31 pm    Dheeraj Lalwani (TSEC CS)
# 116    27/01/2020   7:32 pm    Dheeraj Lalwani (TSEC CS)
# 117    27/01/2020   7:32 pm              +91 96536 93868
# ...           ...        ...                         ...
# 21315  02/10/2020   2:05 am     Darshan Rander (TSEC IT)
# 21316  02/10/2020   2:05 am     Darshan Rander (TSEC IT)
# 21317  02/10/2020   2:05 am     Darshan Rander (TSEC IT)
# 21318  02/10/2020   2:11 am       Tanay Kamath (TSEC CS)
# 21319  02/10/2020   2:28 am     Darshan Rander (TSEC IT)
#
#                                Chat
# 113           <Media omitted>nannan
# 114        Give it a try ....nannan
# 115                      Alrightnan
# 116     We can make this a trendnan
# 117                      Surenannan
# ...                             ...
# ...

# %%
sid = SentimentIntensityAnalyzer()

senti = sid.polarity_scores(dataset["Chat"][114])
senti
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# Apply sentiment analysis to each message
df[['Neg', 'Neu', 'Pos', 'Compound']] = df['Chat'].apply(lambda x: pd.Series(sid.polarity_scores(str(x))))

# Display the first few rows with sentiment scores
print(df.head())
# Out:
#            Date       Time                        Name  \
# 113  27/01/2020   7:31 pm              +91 96536 93868
# 114  27/01/2020   7:31 pm              +91 96536 93868
# 115  27/01/2020   7:31 pm    Dheeraj Lalwani (TSEC CS)
# 116  27/01/2020   7:32 pm    Dheeraj Lalwani (TSEC CS)
# 117  27/01/2020   7:32 pm              +91 96536 93868
#
#                              Chat  Neg  Neu  Pos  Compound
# 113         <Media omitted>nannan  0.0  1.0  0.0       0.0
# 114      Give it a try ....nannan  0.0  1.0  0.0       0.0
# 115                    Alrightnan  0.0  1.0  0.0       0.0
# 116   We can make this a trendnan  0.0  1.0  0.0       0.0
# 117                    Surenannan  0.0  1.0  0.0       0.0

# %%
# Calculate sentiment scores for each message
sentiment_scores = df['Chat'].apply(lambda x: sid.polarity_scores(str(x)))
# Extract the compound score from the sentiment analysis
df['Compound'] = sentiment_scores.apply(lambda score_dict: score_dict['compound'])

# Classify messages as positive, negative, or neutral
df['Sentiment'] = df['Compound'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Neutral'))

# Reorder columns to include sentiment scores
df = df[["Date", "Time", "Name", "Chat","Neg", "Neu", "Pos",  "Compound", "Sentiment"]]

# Save the DataFrame to a CSV file
df.to_csv('whatsapp_chat_sentiment_analysis.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[14], line 12
#       9 df = df[["Date", "Time", "Name", "Chat","Neg", "Neu", "Pos",  "Compound", "Sentiment"]]
#      11 # Save the DataFrame to a CSV file
# ---> 12 df.to_csv('whatsapp_chat_sentiment_analysis.csv', index=False)
#
# File c:\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
